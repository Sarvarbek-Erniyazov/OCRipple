# %%
# !pip install -q huggingface_hub
python -c "
from huggingface_hub import hf_hub_download
p = hf_hub_download('baidu/Unlimited-OCR', 'requirements.txt')
print(open(p).read())
"
# Out:
#   Cell In[1], line 2
#     python -c "
#               ^
# SyntaxError: unterminated string literal (detected at line 2)
